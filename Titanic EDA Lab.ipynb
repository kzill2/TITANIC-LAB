# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# ## TITANIC EDAs

# %% [markdown]
# ### PassengerId EDA

# %% [markdown]
# #### PassengerId is categorical as it labels the Titanic passengers.

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, Length: 891, dtype: int64

# %% [markdown]
# #### There are no missing values of PassengerId.

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### PassengerId Histogram

# %%
df.PassengerId.value_counts().plot(kind='bar')

# %% [markdown]
# ### Survived EDA

# %% [markdown]
# #### Survived is a categorical variable.

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# #### There are no missing values of Survived.

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### Survived Histogram

# %%
df.Survived.value_counts().plot(kind='barh')

# %% [markdown]
# ### Pclass EDA

# %% [markdown]
# #### Pclass is a categorical variable.

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# #### There are no missing values of Pclass.

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### Pclass Histogram

# %%
df.Pclass.value_counts().plot(kind='bar')

# %% [markdown]
# ### Sex EDA

# %% [markdown]
# #### Sex is a categorical variable.

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# #### There are no missing values of Sex.

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### Sex Histogram

# %%
df.Sex.value_counts().plot(kind='bar')

# %% [markdown]
# ### Age EDA

# %% [markdown]
# #### Age is a continuous variable.

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
# 19.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 35.00    18
# 27.00    18
# 32.00    18
# 26.00    18
# 31.00    17
# 16.00    17
# 23.00    15
# 20.00    15
# 33.00    15
# 34.00    15
# 39.00    14
# 40.00    13
# 42.00    13
# 17.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 4.00     10
# 2.00     10
# 48.00     9
#          ..
# 0.75      2
# 40.50     2
# 64.00     2
# 59.00     2
# 57.00     2
# 28.50     2
# 70.00     2
# 55.00     2
# 71.00     2
# 45.50     2
# 63.00     2
# 0.83      2
# 32.50     2
# 30.50     2
# 74.00     1
# 80.00     1
# 0.67      1
# 66.00     1
# 0.92      1
# 24.50     1
# 55.50     1
# 12.00     1
# 14.50     1
# 53.00     1
# 36.50     1
# 70.50     1
# 20.50     1
# 34.50     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %% [markdown]
# #### There are 177 missing values of Age.

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
#
    McCormack, Mr. Thomas Joseph    male  NaN      0
# 881                                  Saad, Mr. Amin    male  NaN      0
# 882                             Sirota, Mr. Maurice    male  NaN      0
# 883                            Marechal, Mr. Pierre    male  NaN      0
# 884                        Sage, Mr. Douglas Bullen    male  NaN      8
# 885    Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  NaN      1
# 886                                Razi, Mr. Raihed    male  NaN      0
# 887               Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8
# 888                     van Melkebeke, Mr. Philemon    male  NaN      0
# 889                              Laleff, Mr. Kristo    male  NaN      0
# 890        Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
#
#      Parch           Ticket      Fare  Cabin Embarked
# 714      0           330877    8.4583    NaN        Q
# 715      0           244373   13.0000    NaN        S
# 716      0             2649    7.2250    NaN        C
# 717      0             2631    7.2250    NaN        C
# 718      0           330959    7.8792    NaN        Q
# 719      0           349216    7.8958    NaN        S
# 720      0         PC 17569  146.5208    B78        C
# 721      0           335677    7.7500    NaN        Q
# 722      0             2677    7.2292    NaN        C
# 723      0           349253    7.8958    NaN        C
# 724      0  S.C./A.4. 23567    8.0500    NaN        S
# 725      0           370371   15.5000    NaN        Q
# 726      0            14311    7.7500    NaN        Q
# 727      0             2662   21.6792    NaN        C
# 728      0            19947   35.5000    C52        S
# 729      0         PC 17605   27.7208    NaN        C
# 730      1             2661   15.2458    NaN        C
# 731      0           349208    7.8958    NaN        S
# 732      0           374746    8.0500    NaN        S
# 733      0           330932    7.7875    NaN        Q
# 734      0  SOTON/OQ 392086    8.0500    NaN        S
# 735      0           374910    8.0500    NaN        S
# 736      0           349215    7.8958    NaN        S
# 737      0           312991    7.7750    NaN        S
# 738      0           371110   24.1500    NaN        Q
# 739      0        A4. 54510    8.0500    NaN        S
# 740      0           370372    7.7500    NaN        Q
# 741      1             2668   22.3583  F E69        C
# 742      2             2678   15.2458    NaN        C
# 743      0        Fa 265302    7.3125    NaN        S
# ..     ...              ...       ...    ...      ...
# 861      0            36568   15.5000    NaN        Q
# 862      0            36866    7.7375    NaN        Q
# 863      0           239855    0.0000    NaN        S
# 864      0           349201    7.8958    NaN        S
# 865      0           349218    7.8958    NaN        S
# 866      0            16988   30.0000    D45        S
# 867      0           358585   14.5000    NaN        S
# 868      0           112379   39.6000    NaN        C
# 869      0           371110   24.1500    NaN        Q
# 870      0             2674    7.2250    NaN        C
# 871      0           383121    7.7500    F38        Q
# 872      0            36865    7.7375    NaN        Q
# 873      2       W./C. 6607   23.4500    NaN        S
# 874      0            12460    7.7500    NaN        Q
# 875      2         CA. 2343   69.5500    NaN        S
# 876      0         PC 17600   30.6958    NaN        C
# 877      0           112058    0.0000   B102        S
# 878      0           368323    6.9500    NaN        Q
# 879      0             1601   56.4958    NaN        S
# 880      0           367228    7.7500    NaN        Q
# 881      0             2671    7.2292    NaN        C
# 882      0           392092    8.0500    NaN        S
# 883      0            11774   29.7000    C47        C
# 884      2         CA. 2343   69.5500    NaN        S
# 885      0            17453   89.1042    C92        C
# 886      0             2629    7.2292    NaN        C
# 887      2         CA. 2343   69.5500    NaN        S
# 888      0           345777    9.5000    NaN        S
# 889      0           349217    7.8958    NaN        S
# 890      2       W./C. 6607   23.4500    NaN        S
#
# [177 rows x 12 columns]

# %% [markdown]
# #### Min, Max, Average and Standard Deviation for Age

# %%
df.Age.min()
# Out:
# 0.41999999999999998

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.Age.std()
# Out:
# 14.526497332334037

# %% [markdown]
# #### Age Histogram

# %%
df.Age.hist()

# %% [markdown]
# ### SibSp EDA

# %% [markdown]
# #### SibSp is a continuous variable.

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %% [markdown]
# #### There are no missing values of SibSp.

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### Min, Max, Average and Standard Deviation for SibSp

# %%
df.SibSp.min()
# Out:
# 0

# %%
df.SibSp.max()
# Out:
# 8

# %%
df.SibSp.mean()
# Out:
# 0.5230078563411896

# %%
df.SibSp.std()
# Out:
# 1.1027434322934286

# %% [markdown]
# #### SibSp Histogram

# %%
df.SibSp.hist(bins=8)

# %% [markdown]
# ### Parch EDA

# %% [markdown]
# #### Parch is a continuous variable.

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# #### There are no missing values of Parch.

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### Max, Min, Average and Standard Deviation for Parch

# %%
df.Parch.min()
# Out:
# 0

# %%
df.Parch.max()
# Out:
# 6

# %%
df.Parch.mean()
# Out:
# 0.38159371492704824

# %%
df.Parch.std()
# Out:
# 0.8060572211299561

# %% [markdown]
# #### Parch Histogram

# %%
df.Parch.hist(bins=6)

# %% [markdown]
# ### Ticket EDA

# %% [markdown]
# #### Ticket is a Categorical variable.

# %%
df.Ticket.value_counts()
# Out:
# 347082           7
# CA. 2343         7
# 1601             7
# 347088           6
# CA 2144          6
# 3101295          6
# 382652           5
# S.O.C. 14879     5
# LINE             4
# 113760           4
# 113781           4
# 347077           4
# PC 17757         4
# 19950            4
# 2666             4
# 17421            4
# 349909           4
# W./C. 6608       4
# 4133             4
# SC/Paris 2123    3
# PC 17572         3
# F.C.C. 13529     3
# 345773           3
# 347742           3
# 24160            3
# 239853           3
# 13502            3
# PC 17582         3
# 248727           3
# C.A. 31921       3
#                 ..
# W/C 14208        1
# PC 17609         1
# 364848           1
# 223596           1
# 384461           1
# 345774           1
# SC/PARIS 2133    1
# 376566           1
# 12460            1
# PC 17612         1
# 312992           1
# 240929           1
# 349243           1
# 374887           1
# 365226           1
# 349236           1
# 349247           1
# 347074           1
# 3474             1
# 6563             1
# 112050           1
# A/5 21171        1
# 14973            1
# 350050           1
# 2693             1
# 2694             1
# C 17369          1
# 239856           1
# 349206           1
# 349227           1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# #### There are no missing values of Ticket.

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Ticket.value_counts().plot(kind='bar')

# %% [markdown]
# ### Fare EDA

# %% [markdown]
# #### Fare is a continuous variable.

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 7.2292      15
# 0.0000      15
# 7.2500      13
# 8.6625      13
# 7.8542      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 15.5000      8
# 24.1500      8
# 52.0000      7
# 14.4542      7
# 69.5500      7
# 31.2750      7
# 56.4958      7
# 14.5000      7
# 7.0500       7
# 26.2500      6
# 30.0000      6
# 39.6875      6
# 27.9000      6
#             ..
# 42.4000      1
# 221.7792     1
# 50.4958      1
# 75.2500      1
# 211.5000     1
# 25.9250      1
# 40.1250      1
# 7.8875       1
# 15.0458      1
# 14.1083      1
# 13.7917      1
# 26.2833      1
# 32.3208      1
# 9.8417       1
# 8.0292       1
# 8.1375       1
# 7.7875       1
# 81.8583      1
# 34.0208      1
# 7.1417       1
# 6.8583       1
# 6.9500       1
# 8.3625       1
# 9.8375       1
# 12.2875      1
# 7.6292       1
# 7.8000       1
# 8.1125       1
# 9.4833       1
# 8.5167       1
# Name: Fare, Length: 248, dtype: int64

# %% [markdown]
# #### There are no missing values of Fare.

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### Min, Max, Average and Standard Deviation of Fare

# %%
df.Fare.min()
# Out:
# 0.0

# %%
df.Fare.max()
# Out:
# 512.32920000000001

# %%
df.Fare.mean()
# Out:
# 32.20420796857458

# %%
df.Fare.std()
# Out:
# 49.693428597180876

# %% [markdown]
# #### Fare Histogram

# %%
df.Fare.hist()

# %% [markdown]
# ### Cabin EDA

# %% [markdown]
# #### Cabin is a categorical variable.

# %%
df.Cabin.value_counts()
# Out:
# B96 B98            4
# C23 C25 C27        4
# G6                 4
# F2                 3
# D                  3
# E101               3
# F33                3
# C22 C26            3
# C83                2
# C92                2
# E44                2
# F G73              2
# B57 B59 B63 B66    2
# C125               2
# B77                2
# D17                2
# C65                2
# D20                2
# B49                2
# B20                2
# C52                2
# E33                2
# F4                 2
# D35                2
# E8                 2
# D26                2
# E121               2
# E24                2
# B58 B60            2
# C123               2
#                   ..
# E63                1
# E68                1
# A7                 1
# A36                1
# C104               1
# E34                1
# D47                1
# C82                1
# D19                1
# A20                1
# B50                1
# D50                1
# A24                1
# D7                 1
# E46                1
# B71                1
# D56                1
# E49                1
# C87                1
# C111               1
# E17                1
# C45                1
# C99                1
# B79                1
# C50                1
# B19                1
# B41                1
# C101               1
# E58                1
# A23                1
# Name: Cabin, Length: 147, dtype: int64

# %% [markdown]
# #### There are 687 missing values of Cabin.

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            804         1       3
# 1            756         1       2
# 2            470         1       3
# 3            645         1       3
# 4             79         1       2
# 5            832         1       2
# 7            165         0       3
# 8            173         1       3
# 10           382         1       3
# 11           387         0       3
# 12           789         1       3
# 13           828         1       2
# 14             8         0       3
# 15            17         0       3
# 16           120         0       3
# 20           480         1       3
# 21           531         1       2
# 22           643         0       3
# 23           825         0       3
# 24            44         1       2
# 26           262         1       3
# 27           349         1       3
# 28           375         0       3
# 29           408         1       2
# 31            64         0       3
# 32           172         0       3
# 33           185         1       3
# 36           692         1       3
# 37           751         1       2
# 38           851         0       3
# ..           ...       ...     ...
# 855          675         0       2
# 856          681         0       3
# 857          693         1       3
# 858          698         1       3
# 859          710         1       3
# 861          719         0       3
# 862          728         1       3
# 863          733         0       2
# 864          739         0       3
# 865          740         0       3
# 867          761         0       3
# 868          767         0       1
# 869          769         0       3
# 870          774         0       3
# 872          779         0       3
# 873          784         0       3
# 874          791         0       3
# 875          793         0       3
# 876          794         0       1
# 878          826         0       3
# 879          827         0       3
# 880          829         1       3
# 881          833         0       3
# 882          838         0       3
# 884          847         0       3
# 886          860         0       3
# 887          864         0       3
# 888          869         0       3
# 889          879         0       3
# 890          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0
Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch           Ticket     Fare Cabin Embarked
# 0        1             2625   8.5167   NaN        C
# 1        1           250649  14.5000   NaN        S
# 2        1             2666  19.2583   NaN        C
# 3        1             2666  19.2583   NaN        C
# 4        2           248738  29.0000   NaN        S
# 5        1            29106  18.7500   NaN        S
# 7        1          3101295  39.6875   NaN        S
# 8        1           347742  11.1333   NaN        S
# 10       2             2653  15.7417   NaN        C
# 11       2          CA 2144  46.9000   NaN        S
# 12       2        C.A. 2315  20.5750   NaN        S
# 13       2  S.C./PARIS 2079  37.0042   NaN        C
# 14       1           349909  21.0750   NaN        S
# 15       1           382652  29.1250   NaN        Q
# 16       2           347082  31.2750   NaN        S
# 20       1          3101298  12.2875   NaN        S
# 21       1            26360  26.0000   NaN        S
# 22       2           347088  27.9000   NaN        S
# 23       1          3101295  39.6875   NaN        S
# 24       2    SC/Paris 2123  41.5792   NaN        C
# 26       2           347077  31.3875   NaN        S
# 27       1       C.A. 37671  15.9000   NaN        S
# 28       1           349909  21.0750   NaN        S
# 29       1            29106  18.7500   NaN        S
# 31       2           347088  27.9000   NaN        S
# 32       1           382652  29.1250   NaN        Q
# 33       2           315153  22.0250   NaN        S
# 36       1           349256  13.4167   NaN        C
# 37       1            29103  23.0000   NaN        S
# 38       2           347082  31.2750   NaN        S
# ..     ...              ...      ...   ...      ...
# 855      0           239856   0.0000   NaN        S
# 856      0           330935   8.1375   NaN        Q
# 857      0             1601  56.4958   NaN        S
# 858      0            35852   7.7333   NaN        Q
# 859      1             2661  15.2458   NaN        C
# 861      0            36568  15.5000   NaN        Q
# 862      0            36866   7.7375   NaN        Q
# 863      0           239855   0.0000   NaN        S
# 864      0           349201   7.8958   NaN        S
# 865      0           349218   7.8958   NaN        S
# 867      0           358585  14.5000   NaN        S
# 868      0           112379  39.6000   NaN        C
# 869      0           371110  24.1500   NaN        Q
# 870      0             2674   7.2250   NaN        C
# 872      0            36865   7.7375   NaN        Q
# 873      2       W./C. 6607  23.4500   NaN        S
# 874      0            12460   7.7500   NaN        Q
# 875      2         CA. 2343  69.5500   NaN        S
# 876      0         PC 17600  30.6958   NaN        C
# 878      0           368323   6.9500   NaN        Q
# 879      0             1601  56.4958   NaN        S
# 880      0           367228   7.7500   NaN        Q
# 881      0             2671   7.2292   NaN        C
# 882      0           392092   8.0500   NaN        S
# 884      2         CA. 2343  69.5500   NaN        S
# 886      0             2629   7.2292   NaN        C
# 887      2         CA. 2343  69.5500   NaN        S
# 888      0           345777   9.5000   NaN        S
# 889      0           349217   7.8958   NaN        S
# 890      2       W./C. 6607  23.4500   NaN        S
#
# [687 rows x 12 columns]

# %% [markdown]
# #### Cabin Histogram

# %%
df.Cabin.value_counts().plot(kind='bar')

# %% [markdown]
# ### Embarked EDA

# %% [markdown]
# #### Embarked is a categorical variable.

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# #### There are two missing values of Embarked.

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 528           62         1       1                        Icard, Miss. Amelie
# 698          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 528  female  38.0      0      0  113572  80.0   B28      NaN
# 698  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# #### Embarked Histrogram

# %%
df.Embarked.value_counts().plot(kind='bar')

# %% [markdown]
# ## CHECK FOR CONTINUOUS VARIABLES

# %% [markdown]
# #### Note: PassengerId, Survived and Pclass are not continuous variables. Although they are numerical, their purpose is to label items. Thus, they cannot be continuous variables.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
